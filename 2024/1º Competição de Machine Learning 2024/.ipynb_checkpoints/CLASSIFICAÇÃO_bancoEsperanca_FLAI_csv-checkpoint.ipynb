# %% [markdown]
# <!-- CLASSIFICAÇÃO_bancoEsperanca_FLAI_csv -->
# <!-- # Desafio:
# <!-- ajudar o Banco Esperança e o Sr. Cauteloso a construir o cérebro do Previsor, de forma a maximizar os ganhos de moedas de ouro! -->
# <!-- data prevista para deadline: 27/03/2024 -->

# %%
# Desafio
# ajudar o Banco Esperança e o Sr. Cauteloso a construir o cérebro do Previsor, de forma a maximizar os ganhos de moedas de ouro!

# variável alvo
# status_do_emprestimo: empréstimo foi pago ou não

# %%
# Import libs
import pandas as pd

# %%
# fonte de dados
# https://flavia-flai.streamlit.app/Competi%C3%A7%C3%B5es_FLAI
df_train = pd.read_csv('treino.csv')
df_test = pd.read_csv('teste.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   montante_financiado       10000 non-null  float64
#  1   prazo                     10000 non-null  object
#  2   taxa_de_juros             10000 non-null  object
#  3   parcela                   10000 non-null  float64
#  4   tempo_de_emprego          9696 non-null   object
#  5   propriedade_de_casa       10000 non-null  object
#  6   renda_anual               9999 non-null   float64
#  7   status_de_verificacao     10000 non-null  object
#  8   status_do_emprestimo      10000 non-null  object
#  9   finalidade                10000 non-null  object
#  10  divida_sobre_renda        10000 non-null  object
#  11  inadimplencias_2_anos     10000 non-null  int64
#  12  score_de_credito          9999 non-null   float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   montante_financiado       4000 non-null   float64
#  1   prazo                     4000 non-null   object
#  2   taxa_de_juros             4000 non-null   object
#  3   parcela                   4000 non-null   float64
#  4   tempo_de_emprego          3888 non-null   object
#  5   propriedade_de_casa       4000 non-null   object
#  6   renda_anual               4000 non-null   float64
#  7   status_de_verificacao     4000 non-null   object
#  8   finalidade                4000 non-null   object
#  9   divida_sobre_renda        4000 non-null   object
#  10  inadimplencias_2_anos     4000 non-null   int64
#  11  score_de_credito          4000 non-null   float64
#  12  numero_de_dependentes     4000 non-null   int64
# ...

# %%
df_train.tail().T
# Out:
#                                             9995             9996  \
# montante_financiado                      19466.0           7549.0
# prazo                                      Curto            Curto
# taxa_de_juros                               7.9%            14.3%
# parcela                                   619.54           265.19
# tempo_de_emprego                 mais de 10 anos  mais de 10 anos
# propriedade_de_casa                   Empréstimo          Alugado
# renda_anual                              70000.0          41400.0
# status_de_verificacao           Fonte Verificada   Não Verificado
# status_do_emprestimo                        Pago         Não Pago
# finalidade                Consolidação de Dívida            Outro
# divida_sobre_renda                         13.8%            23.8%
# inadimplencias_2_anos                          0                1
# score_de_credito                      449.730968       482.825254
# ...

# %%
df_test.tail().T
# Out:
#                                             3995                    3996  \
# montante_financiado                       6260.0                 10040.0
# prazo                                      Longo                   Curto
# taxa_de_juros                               9.2%                    7.9%
# parcela                                   137.13                  320.28
# tempo_de_emprego                          3 anos                  5 anos
# propriedade_de_casa                      Alugado              Empréstimo
# renda_anual                              35000.0                106000.0
# status_de_verificacao             Não Verificado              Verificado
# finalidade                Consolidação de Dívida  Consolidação de Dívida
# divida_sobre_renda                         23.5%                   12.3%
# inadimplencias_2_anos                          0                       0
# score_de_credito                      354.398801              294.129768
# ...

# %%
df_train.isnull().sum()
# Out:
# montante_financiado           0
# prazo                         0
# taxa_de_juros                 0
# parcela                       0
# tempo_de_emprego            304
# propriedade_de_casa           0
# renda_anual                   1
# status_de_verificacao         0
# status_do_emprestimo          0
# finalidade                    0
# divida_sobre_renda            0
# inadimplencias_2_anos         0
# score_de_credito              1
# numero_de_dependentes         0
# anos_na_residencia_atual      0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# montante_financiado           0
# prazo                         0
# taxa_de_juros                 0
# parcela                       0
# tempo_de_emprego            112
# propriedade_de_casa           0
# renda_anual                   0
# status_de_verificacao         0
# finalidade                    0
# divida_sobre_renda            0
# inadimplencias_2_anos         0
# score_de_credito              0
# numero_de_dependentes         0
# anos_na_residencia_atual      0
# dtype: int64
